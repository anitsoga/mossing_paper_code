# %%
import sim_utils
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
plt.figure()
x = np.linspace(-2,2,100)
a = 0.1
cost = (x-a*sim_utils.f_miller_troyer(x,1))**2
plt.plot(x,cost)
plt.axhline(cost.min(),c='k',linestyle='dashed')
# Out:
# <img src="data:image/png;base64,..." width="640">
