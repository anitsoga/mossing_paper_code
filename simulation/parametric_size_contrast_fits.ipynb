# %%
import nub_utils
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import scipy.optimize as sop

# %%
RD = 77
RS = 133
R0 = 11
delta = 0
sigma_D = 7.3
sigma_S = 36.4
n = 1
m = 1.2
S,D = [lambda d: nub_utils.compute_overlap(np.array((delta,0))/d,sigma/d**2) for sigma in [sigma_S,sigma_D]]
def R(c,d):
    return R0 + RD*c**n*D(d)**m/(1+RS*c**n*S(d)**m)

# %%
plt.figure()
ucontrast = np.array((0,6,12,25,50,100))/100
usize = np.array((5,8,13,22,36,60))
for this_size in usize:
    plt.plot(ucontrast,R(ucontrast,this_size))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dx,dy = 0.01,0.01
x = np.arange(-1,1,dx)
y = np.arange(-1,1,dy)

# %%
xx,yy = np.meshgrid(x,y)

# %%
plt.figure()
g = 1/(2*np.pi)*np.exp(-(xx**2+yy**2)/2)
np.sum(g*dx*dy)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.4660594363099335

# %%
plt.figure()
plt.imshow(xx)
# Out:
# <img src="data:image/png;base64,..." width="640">
